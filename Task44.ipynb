# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaVAM/Python/blob/master/Task44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import random

# %%
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
pd.get_dummies(data, columns=['whoAmI'])
# Out:
#     whoAmI_human  whoAmI_robot
# 0              1             0
# 1              0             1
# 2              1             0
# 3              0             1
# 4              0             1
# 5              1             0
# 6              0             1
# 7              1             0
# 8              1             0
# 9              1             0
# 10             1             0
# 11             1             0
# 12             0             1
# 13             0             1
# 14             1             0
# 15             0             1
# 16             1             0
# 17             0             1
# 18             0             1
# 19             0             1

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehotencoder = OneHotEncoder()
data_new = onehotencoder.fit_transform(data.values)
pd.DataFrame(data_new.toarray(),
columns=onehotencoder.categories_).head(20)
# Out:
#    human robot
# 0    1.0   0.0
# 1    0.0   1.0
# 2    1.0   0.0
# 3    0.0   1.0
# 4    0.0   1.0
# 5    1.0   0.0
# 6    0.0   1.0
# 7    1.0   0.0
# 8    1.0   0.0
# 9    1.0   0.0
# 10   1.0   0.0
# 11   1.0   0.0
# 12   0.0   1.0
# 13   0.0   1.0
# 14   1.0   0.0
# 15   0.0   1.0
# 16   1.0   0.0
# 17   0.0   1.0
# 18   0.0   1.0
# 19   0.0   1.0
